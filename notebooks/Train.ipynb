# %% [markdown]
# # **Import Modules:**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# # **Load Dataset:**

# %%
raw_data = pd.read_csv('../data/train.csv')
df = raw_data.copy()
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %% [markdown]
# # **Check Dataset:**

# %%
print(df.head())
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %% [markdown]
# # **Dataset Cleaning**

# %% [markdown]
# ## Check Dataset for NULL value:

# %%
df.isna().sum()    # df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %% [markdown]
# ## View NULL value:

# %%
df[df['Postal Code'].isna()]     # can also used 'isnull()'
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2234    2235  CA-2018-104066  05/12/2018  10/12/2018  Standard Class
# 5274    5275  CA-2016-162887  07/11/2016  09/11/2016    Second Class
# 8798    8799  US-2017-150140  06/04/2017  10/04/2017  Standard Class
# 9146    9147  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9147    9148  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9148    9149  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9386    9387  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9387    9388  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9388    9389  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9389    9390  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9741    9742  CA-2016-117086  08/11/2016  12/11/2016  Standard Class
#
#      Customer ID     Customer Name      Segment        Country        City  \
# ...

# %% [markdown]
# ## Fill 'Postal Code' NULL:

# %%
df['Postal Code'] = df['Postal Code'].fillna('05401')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9800 non-null   object
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# dtype: int64

# %% [markdown]
# ## Format "Order Date", "Ship Date" and "Postal Code" data type:

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], format='%d/%m/%Y')
df['Order Date']
# Out:
# 0      2017-11-08
# 1      2017-11-08
# 2      2017-06-12
# 3      2016-10-11
# 4      2016-10-11
#           ...
# 9795   2017-05-21
# 9796   2016-01-12
# 9797   2016-01-12
# 9798   2016-01-12
# 9799   2016-01-12
# Name: Order Date, Length: 9800, dtype: datetime64[ns]

# %%
df['Ship Date'] = pd.to_datetime(df['Ship Date'], format='%d/%m/%Y')
df['Ship Date']
# Out:
# 0      2017-11-11
# 1      2017-11-11
# 2      2017-06-16
# 3      2016-10-18
# 4      2016-10-18
#           ...
# 9795   2017-05-28
# 9796   2016-01-17
# 9797   2016-01-17
# 9798   2016-01-17
# 9799   2016-01-17
# Name: Ship Date, Length: 9800, dtype: datetime64[ns]

# %%
df['Postal Code'] = df['Postal Code'].astype(int).astype(str)
df['Postal Code']
# Out:
# 0       42420
# 1       42420
# 2       90036
# 3       33311
# 4       33311
#         ...
# 9795    60610
# 9796    43615
# 9797    43615
# 9798    43615
# 9799    43615
# Name: Postal Code, Length: 9800, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   datetime64[ns]
#  3   Ship Date      9800 non-null   datetime64[ns]
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9800 non-null   object
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %% [markdown]
# ## Create "Order Year" column from "Order Date":

# %%
df['Order Year'] = df['Order Date'].dt.year
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-06-12 2017-06-16    Second Class    DV-13045
# 3       4  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %% [markdown]
# # **Dataset Grouping:**

# %% [markdown]
# ## Yearly Sales Trend:

# %%
yearly_sales_trend = df.groupby('Order Year', as_index=False).agg({'Sales': 'sum'})
yearly_sales_trend
# Out:
#    Order Year        Sales
# 0        2015  479856.2081
# 1        2016  459436.0054
# 2        2017  600192.5500
# 3        2018  722052.0192

# %% [markdown]
# ### Yearly Sales Trend Visualization:

# %%
#sns.set_style('whitegrid')
sns.lineplot(x='Order Year',
             y='Sales',
             data=yearly_sales_trend)
plt.xlabel('Year')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# ## Product Sold the Most in 2018:

# %% [markdown]
# ### Create DataFrame in year 2018:

# %%
df_2018 = df[df['Order Year'] == 2018]
df_2018.head()
# Out:
#     Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 12      13  CA-2018-114412 2018-04-15 2018-04-20  Standard Class    AA-10480
# 23      24  US-2018-156909 2018-07-16 2018-07-18    Second Class    SF-20065
# 34      35  CA-2018-107727 2018-10-19 2018-10-23    Second Class    MA-17560
# 41      42  CA-2018-120999 2018-09-10 2018-09-15  Standard Class    LC-16930
# 43      44  CA-2018-139619 2018-09-19 2018-09-23  Standard Class    ES-14080
#
#       Customer Name      Segment        Country          City           State  \
# 12     Andrew Allen     Consumer  United States       Concord  North Carolina
# 23  Sandra Flanagan     Consumer  United States  Philadelphia    Pennsylvania
# 34     Matt Abelman  Home Office  United States       Houston           Texas
# 41   Linda Cazamias    Corporate  United States    Naperville        Illinois
# 43       Erin Smith    Corporate  United States     Melbourne         Florida
#
# ...

# %% [markdown]
# ### Groupby 2018 Sales by "Product Name":

# %%
prod_grp_2018 = df_2018.groupby('Product Name', as_index=False).agg({'Sales': 'sum'})
prod_grp_2018.head()
# Out:
#                                         Product Name   Sales
# 0  "While you Were Out" Message Book, One Form pe...  25.228
# 1           #10 Gummed Flap White Envelopes, 100/Box   9.912
# 2                      #10 Self-Seal White Envelopes  22.180
# 3         #10 White Business Envelopes,4 1/8 x 9 1/2  84.618
# 4            #10- 4 1/8" x 9 1/2" Recycled Envelopes  89.148

# %% [markdown]
# ### Sort Product Sold in 2018:

# %%
prod_grp_2018 = prod_grp_2018.sort_values(by='Sales', ascending=False)
prod_grp_2018.head()
# Out:
#                                            Product Name      Sales
# 337               Canon imageCLASS 2200 Advanced Copier  35699.898
# 859   Martin Yale Chadless Opener Electric Letter Op...  11825.902
# 567          GBC DocuBind TL300 Electric Binding System  10943.278
# 668                Hewlett Packard LaserJet 3310 Copier   9239.846
# 1135                            Samsung Galaxy Mega 6.3   9239.780

# %% [markdown]
# #### Most Product Sold in 2018 Visualization:

# %%
top_product = prod_grp_2018[prod_grp_2018['Sales'] >= 4416.174]
sns.set_style('whitegrid')
sns.barplot(y='Product Name',
            x='Sales',
            data=top_product,
            errorbar=('ci', False),
            orient='h',
            color='grey')
plt.title('Top Products in 2018')
plt.ylabel(' ')
plt.show()

# %% [markdown]
# ## Sales by "Segment":

# %%
df['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %% [markdown]
# ### Yearly Sales Trend by "Consumer Segment":

# %%
cons_segment = df[df['Segment'] == 'Consumer']
cons_segment = cons_segment.groupby('Order Year', as_index=False).agg({'Sales': 'sum'})
cons_segment
# Out:
#    Order Year        Sales
# 0        2015  262956.8006
# 1        2016  265356.2933
# 2        2017  291142.9652
# 3        2018  328604.4719

# %% [markdown]
# #### Yearly Sales Trend by "Consumer Segment" Visualization:

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
sns.barplot(x='Order Year',
            y='Sales',
            data=cons_segment,
            color='skyblue')
plt.xlabel('Year')
plt.ylabel('Total Sales'),
plt.title('Yearly Sales Trend for Consumer Segment')
plt.show()

# %% [markdown]
# ### Yearly Sales Trend by "Corporate Segment":

# %%
corp_segment = df[df['Segment'] == 'Corporate']
corp_segment = corp_segment.groupby('Order Year', as_index=False).agg({'Sales': 'sum'})
corp_segment
# Out:
#    Order Year        Sales
# 0        2015  127797.4957
# 1        2016  119675.5989
# 2        2017  204977.3178
# 3        2018  236043.6624

# %% [markdown]
# #### Yearly Sales Trend by "Corporate Segment" Visualization:

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
sns.barplot(x='Order Year',
            y='Sales',
            data=corp_segment,
            color='skyblue')
plt.xlabel('Year')
plt.ylabel('Total Sales'),
plt.title('Yearly Sales Trend for Corporate Segment')
plt.show()

# %% [markdown]
# ### Yearly Sales Trend by "Home Office Segment":

# %%
home_off_segment = df[df['Segment'] == 'Home Office']
home_off_segment = home_off_segment.groupby('Order Year', as_index=False).agg({'Sales': 'sum'})
home_off_segment
# Out:
#    Order Year        Sales
# 0        2015   89101.9118
# 1        2016   74404.1132
# 2        2017  104072.2670
# 3        2018  157403.8849

# %% [markdown]
# #### Yearly Sales Trend by "Home Office Segment" Visualization:

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
sns.barplot(x='Order Year',
            y='Sales',
            data=home_off_segment,
            color='skyblue')
plt.xlabel('Year')
plt.ylabel('Total Sales'),
plt.title('Yearly Sales Trend for Home Office Segment')
plt.show()

# %% [markdown]
# ## 2018 Sales by "Category":

# %%
category_2018 = df_2018.groupby('Category', as_index=False).agg({'Sales': 'sum'})
category_2018
# Out:
#           Category        Sales
# 0        Furniture  212313.7872
# 1  Office Supplies  240367.5410
# 2       Technology  269370.6910

# %% [markdown]
# #### 2018 Sales by "Category" Visualization:

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
sns.barplot(x='Category',
            y='Sales',
            data=category_2018,
            color='skyblue')
plt.xlabel('Category')
plt.ylabel('Total Sales'),
plt.title('2018 Sales by "Category"')
plt.show()
